# %% [markdown]
# <a href="https://colab.research.google.com/github/ericliudx/ISE585HW11/blob/main/ISE585HW11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1
#
# Using the method of moments, we find the first moment $E(X)$
#
# $$E(x) = \beta / (\beta - 1)$$

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/content/Sample data for Problem 1 Assignment 11 Fall 2025.xlsx", header=None)


# convert to NumPy array
x = df.values.flatten()      # 1D NumPy array

# %%
xbar = np.mean(x)
print(xbar)
# Out:
# 5301.874597632665

# %%
beta_mom = xbar / (xbar - 1)

print("Sample mean:", xbar)
print("MoM estimate beta:", beta_mom)
# Out:
# Sample mean: 5301.874597632665
# MoM estimate beta: 1.000188648114869

# %% [markdown]
# Question 2
#
# $$M(x) = E(e^{tx}) = \int^\theta_0 e^{tx} \frac{2}{\theta^2} (\theta-x)dx = \frac{2}{\theta ^2} (\theta * \frac{e^{t\theta}-1}{t} - \frac{e^{t\theta}(t\theta-1)+1}{t^2}$$
# $$M'(0) = \frac{\theta}{3}$$

# %%
df = pd.read_excel("/content/Sample data for Problem 2 Assignment 11 Fall 2025.xlsx", header=None)


# convert to NumPy array
x = df.values.flatten()      # 1D NumPy array

# %%
xbar = np.mean(x)
print(xbar)
# Out:
# 1.7091532252216632

# %%
theta_mom = xbar * 3

print("Sample mean:", xbar)
print("MoM estimate beta:", theta_mom)
# Out:
# Sample mean: 1.7091532252216632
# MoM estimate beta: 5.12745967566499

# %% [markdown]
# Question 3
#
# First moment:
# $$E(X) = e^{\mu + \sigma ^2/2}$$
#
# Second moment:
# $$E(X^2) = e^{2\mu + 2\sigma^2}$$
#
# Solving for the parameters,
# $\sigma^2 = \ln (m2/m1^2)$ and $\mu = \ln m1 - 1/2(\sigma^2)$, where m1 and m2 are the first two sample moments.
